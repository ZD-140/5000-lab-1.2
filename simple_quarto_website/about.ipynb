# %% [raw]
# ---
# title: "About"
# ---

# %% [markdown]
# # Section A: Requirement
# This section includes some explanations and a random graph.

# %% [markdown]
# ## Subsection A.1: Description
# There will be a small graph.

# %% [markdown]
# ### A.1.1

# %%
import matplotlib.pyplot as plt
import numpy as np

# random data
x = np.linspace(0, 10, 100)
y = x + np.random.randn(100) 

# Create plot
plt.figure(figsize=(10,6))
plt.plot(x, y, '-r', label='Random Data')
plt.title('Random Data Plot')
plt.xlabel('x', color='#1C2833')
plt.ylabel('y', color='#1C2833')
plt.legend(loc='upper left')
plt.grid()
plt.show()
